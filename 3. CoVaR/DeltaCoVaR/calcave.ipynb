# %%
# %matplotlib inline
import seaborn as sns 
from scipy import stats
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
plt.rcParams['font.sans-serif'] = ['SimHei'] 
plt.rcParams['axes.unicode_minus'] = False

# %%
da = pd.read_csv(r'3VaR and CoVaR Result.csv', header = 0, index_col = 0)
da
# Out:
#                VaR1D     VaR2D     VaR3D     VaR4D     VaR1U     VaR2U  \
# Date
# 2016-12-01 -0.011708 -0.011231 -0.015219 -0.011209  0.018634  0.012539
# 2016-12-02 -0.011821 -0.011366 -0.014749 -0.012170  0.018747  0.012674
# 2016-12-05 -0.012821 -0.013030 -0.015723 -0.011673  0.019747  0.014338
# 2016-12-06 -0.014304 -0.013933 -0.016090 -0.010969  0.021230  0.015241
# 2016-12-07 -0.013843 -0.013430 -0.015590 -0.010332  0.020769  0.014738
# ...              ...       ...       ...       ...       ...       ...
# 2021-04-07 -0.022311 -0.027423 -0.020811 -0.014446  0.029237  0.028731
# 2021-04-08 -0.021299 -0.027031 -0.020436 -0.013566  0.028225  0.028339
# 2021-04-09 -0.020079 -0.025697 -0.019908 -0.012735  0.027005  0.027005
# 2021-04-12 -0.020575 -0.026076 -0.020084 -0.011938  0.027501  0.027384
# 2021-04-13 -0.021336 -0.027575 -0.020115 -0.011410  0.028262  0.028883
#
#                VaR3U     VaR4U  CoVaR1DL  CoVaR1DR  ...  CoVaR4UL  CoVaR4UR  \
# ...

# %%
da.mean()
# Out:
# VaR1D      -0.019699
# VaR2D      -0.022998
# VaR3D      -0.019178
# VaR4D      -0.019892
# VaR1U       0.026625
# VaR2U       0.024306
# VaR3U       0.019246
# VaR4U       0.021322
# CoVaR1DL   -0.046756
# CoVaR1DR   -0.054313
# CoVaR1UL    0.048064
# CoVaR1UR    0.061239
# CoVaR2DL   -0.037364
# CoVaR2DR   -0.048888
# CoVaR2UL    0.036350
# CoVaR2UR    0.055814
# CoVaR3DL   -0.024514
# CoVaR3DR   -0.024885
# CoVaR3UL    0.025944
# CoVaR3UR    0.031811
# CoVaR4DL   -0.036308
# CoVaR4DR   -0.042750
# CoVaR4UL    0.035357
# CoVaR4UR    0.044058
# CoVaR5DL   -0.026348
# CoVaR5DR   -0.029349
# CoVaR5UL    0.043012
# CoVaR5UR    0.042507
# CoVaR6DL   -0.030953
# CoVaR6DR   -0.028113
# CoVaR6UL    0.044329
# CoVaR6UR    0.034785
# dtype: float64

# %%
da = pd.read_csv(r'3DeltaCoVaR Result.csv', header = 0, index_col = 0)
da
# Out:
#             DCoVaR1DL  DCoVaR2DL  DCoVaR3DL  DCoVaR4DL  DCoVaR5DL  DCoVaR6DL  \
# da[, 1]
# 2016-12-01  -0.011939  -0.014495  -0.002675  -0.013653  -0.003736  -0.006400
# 2016-12-02  -0.012074  -0.014057  -0.002890  -0.013240  -0.004037  -0.006916
# 2016-12-05  -0.013746  -0.014965  -0.002779  -0.014096  -0.003881  -0.006649
# 2016-12-06  -0.014653  -0.015307  -0.002621  -0.014418  -0.003661  -0.006272
# 2016-12-07  -0.014147  -0.014841  -0.002478  -0.013979  -0.003461  -0.005929
# ...               ...        ...        ...        ...        ...        ...
# 2021-04-07  -0.028204  -0.019708  -0.003401  -0.018563  -0.004750  -0.008137
# 2021-04-08  -0.027810  -0.019358  -0.003203  -0.018233  -0.004474  -0.007665
# 2021-04-09  -0.026470  -0.018866  -0.003017  -0.017770  -0.004214  -0.007219
# 2021-04-12  -0.026850  -0.019030  -0.002838  -0.017925  -0.003964  -0.006791
# 2021-04-13  -0.028356  -0.019059  -0.002720  -0.017952  -0.003799  -0.006508
#
# ...

# %%
da.mean()
# Out:
# DCoVaR1DL   -0.023759
# DCoVaR2DL   -0.018186
# DCoVaR3DL   -0.004622
# DCoVaR4DL   -0.017130
# DCoVaR5DL   -0.006456
# DCoVaR6DL   -0.011061
# VaR1D       -0.034614
# DCoVaR2DR   -0.029189
# DCoVaR3DR   -0.005186
# DCoVaR4DR   -0.019752
# DCoVaR5DR   -0.006351
# DCoVaR6DR   -0.008934
# DCoVaR1UL    0.023759
# DCoVaR2UL    0.017104
# DCoVaR3UL    0.004622
# DCoVaR4UL    0.016111
# DCoVaR5UL    0.021689
# DCoVaR6UL    0.023007
# DCoVaR1UR    0.036933
# DCoVaR2UR    0.036568
# DCoVaR3UR    0.010488
# DCoVaR4UR    0.024812
# DCoVaR5UR    0.021185
# DCoVaR6UR    0.013463
# dtype: float64

# %%
da = pd.read_csv(r'3PerceCoVaR Result.csv', header = 0, index_col = 0)
da
# Out:
#             PCoVaR1DL  PCoVaR2DL  PCoVaR3DL  PCoVaR4DL  PCoVaR5DL  PCoVaR6DL  \
# da[, 1]
# 2016-12-01   1.063008   0.952433   0.238621   0.897102   0.333277   0.570976
# 2016-12-02   1.062316   0.953077   0.237492   0.897709   0.331700   0.568274
# 2016-12-05   1.054931   0.951784   0.238054   0.896491   0.332484   0.569617
# 2016-12-06   1.051665   0.951338   0.238934   0.896071   0.333715   0.571725
# 2016-12-07   1.053431   0.951952   0.239837   0.896649   0.334975   0.573884
# ...               ...        ...        ...        ...        ...        ...
# 2021-04-07   1.028469   0.947001   0.235416   0.891986   0.328800   0.563306
# 2021-04-08   1.028817   0.947273   0.236136   0.892242   0.329806   0.565029
# 2021-04-09   1.030078   0.947672   0.236907   0.892618   0.330883   0.566875
# 2021-04-12   1.029707   0.947536   0.237748   0.892490   0.332058   0.568886
# 2021-04-13   1.028338   0.947512   0.238370   0.892468   0.332926   0.570374
#
# ...

# %%
da.mean()
# Out:
# PCoVaR1DL    1.035574
# PCoVaR2DL    0.949665
# PCoVaR3DL    0.235781
# PCoVaR4DL    0.894495
# PCoVaR5DL    0.329310
# PCoVaR6DL    0.564178
# VaR1D        1.807572
# PCoVaR2DR    1.524293
# PCoVaR3DR    0.270801
# PCoVaR4DR    0.860941
# PCoVaR5DR    0.276815
# PCoVaR6DR    0.466548
# PCoVaR1UL    0.975398
# PCoVaR2UL    0.887428
# PCoVaR3UL    0.214129
# PCoVaR4UL    0.835919
# PCoVaR5UL    1.004740
# PCoVaR6UL    1.065778
# PCoVaR1UR    1.498376
# PCoVaR2UR    1.962158
# PCoVaR3UR    0.850356
# PCoVaR4UR    1.357023
# PCoVaR5UR    1.503965
# PCoVaR6UR    0.995409
# dtype: float64
